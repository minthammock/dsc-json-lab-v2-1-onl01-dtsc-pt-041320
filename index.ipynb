# %% [markdown]
# # JSON - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, you'll practice navigating JSON data structures.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Use the JSON module to load and parse JSON documents

# %% [markdown]
# ## JSON

# %% [markdown]
# ### Open the dataset from json

# %%
import json
import pandas as pd

# %%
file = open('nyc_2001_campaign_finance.json')

# %% [markdown]
# ### What is the root data type of the json file?

# %%
data = json.load(file)

# %%
for x in data.keys():
    print(x)
# Out:
# meta
# data

# %%
metaData = pd.DataFrame(data['meta'])
fileData = pd.DataFrame(data['data'])
display(metaData.head(),
fileData.head())
data['meta']
columns = [x['name'] for x in data['meta']['view']['columns']]
len(columns)
fileData.columns = columns
# Out:
#                                                             view
# attribution                         Campaign Finance Board (CFB)
# averageRating                                                  0
# category                                         City Government
# columns        [{'id': -1, 'name': 'sid', 'dataTypeName': 'me...
# createdAt                                             1315950830
#    0                                     1  2           3       4           5  \
# 0  1  E3E9CC9F-7443-43F6-94AF-B5A0F802DBA1  1  1315925633  392904  1315925633
# 1  2  9D257416-581A-4C42-85CC-B6EAD9DED97F  2  1315925633  392904  1315925633
# 2  3  B80D7891-93CF-49E8-86E8-182B618E68F2  3  1315925633  392904  1315925633
# 3  4  BB012003-78F5-406D-8A87-7FF8A425EE3F  4  1315925633  392904  1315925633
# 4  5  945825F9-2F5D-47C2-A16B-75B93E61E1AD  5  1315925633  392904  1315925633
#
#         6                                                  7     8       9  \
# ...

# %%
fileData
# Out:
#      sid                                    id  position  created_at  \
# 0      1  E3E9CC9F-7443-43F6-94AF-B5A0F802DBA1         1  1315925633
# 1      2  9D257416-581A-4C42-85CC-B6EAD9DED97F         2  1315925633
# 2      3  B80D7891-93CF-49E8-86E8-182B618E68F2         3  1315925633
# 3      4  BB012003-78F5-406D-8A87-7FF8A425EE3F         4  1315925633
# 4      5  945825F9-2F5D-47C2-A16B-75B93E61E1AD         5  1315925633
# ..   ...                                   ...       ...         ...
# 280  281  C50E6A4C-BDE9-4F12-97F4-95D467013540       281  1315925633
# 281  282  04C6D19F-FF63-47B0-B26D-3B8F98B4C16B       282  1315925633
# 282  283  A451E0E9-D382-4A97-AAD8-D7D382055F8D       283  1315925633
# 283  284  E84BCD0C-D6F4-450F-B55B-3199A265C781       284  1315925633
# 284  285  5BBC9676-2119-4FB5-9DAB-DE3F71B7681A       285  1315925633
#
#     created_meta  updated_at updated_meta  \
# 0         392904  1315925633       392904
# 1         392904  1315925633       392904
# ...

# %%
for x in data.keys():
    print(type(data[x]))

# %% [markdown]
# ### Navigate to the 'data' key of your loaded json object. What data type is this?

# %% [markdown]
# ### Preview the first entry from the value returned by the 'data' key above.

# %%
#Your code here

# %% [markdown]
# ### Preview the Entry under meta -> view -> columns (the keys of three successively nested dictionaries)

# %%
# Your code here

# %% [markdown]
# ### Create a DataFrame from your json data
# The previous two questions previewed one entry from the data object within the json file, as well as the column details associated with that data from the meta entry within the json file. Both should have 19 entries. Create a pandas DataFrame of the data. Be sure to use the information from the meta entry to add appropriate column names to your DataFrame.

# %%
#Your code here

# %% [markdown]
# ### What's wrong with the first row of the DataFrame?

# %%
fileData[0:1]
# Out:
#    sid                                    id  position  created_at  \
# 0    1  E3E9CC9F-7443-43F6-94AF-B5A0F802DBA1         1  1315925633
#
#   created_meta  updated_at updated_meta  \
# 0       392904  1315925633       392904
#
#                                                 meta ELECTION  CANDID  \
# 0  {\n  "invalidCells" : {\n    "1519001" : "TOTA...     None  CANDID
#
#    CANDNAME OFFICECD  OFFICEBORO OFFICEDIST  CANCLASS PRIMARYPAY GENERALPAY  \
# 0  CANDNAME     None  OFFICEBORO       None  CANCLASS       None       None
#
#   RUNOFFPAY TOTALPAY
# 0      None     None

# %% [markdown]
# This appears to be an attempt to store the column names in the first from of the JSON string. It looks like pandas had a hard time dealing with the new line char '\n' and errored out most of the entries. Because we took the column names directly from the meta data I think it's appropriate to drop this row.

# %%
fileData = fileData.drop([0]);

# %%
fileData
# Out:
#      sid                                    id  position  created_at  \
# 1      2  9D257416-581A-4C42-85CC-B6EAD9DED97F         2  1315925633
# 2      3  B80D7891-93CF-49E8-86E8-182B618E68F2         3  1315925633
# 3      4  BB012003-78F5-406D-8A87-7FF8A425EE3F         4  1315925633
# 4      5  945825F9-2F5D-47C2-A16B-75B93E61E1AD         5  1315925633
# 5      6  9546F502-39D6-4340-B37E-60682EB22274         6  1315925633
# ..   ...                                   ...       ...         ...
# 280  281  C50E6A4C-BDE9-4F12-97F4-95D467013540       281  1315925633
# 281  282  04C6D19F-FF63-47B0-B26D-3B8F98B4C16B       282  1315925633
# 282  283  A451E0E9-D382-4A97-AAD8-D7D382055F8D       283  1315925633
# 283  284  E84BCD0C-D6F4-450F-B55B-3199A265C781       284  1315925633
# 284  285  5BBC9676-2119-4FB5-9DAB-DE3F71B7681A       285  1315925633
#
#     created_meta  updated_at updated_meta  meta ELECTION CANDID  \
# 1         392904  1315925633       392904  {\n}     2001     B4
# ...

# %% [markdown]
# ## Summary
#
# Congratulations! You've started exploring some more JSON data structures used for the web and got to practice data munging and exploring!
